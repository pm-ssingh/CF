# %% [markdown]
# <a href="https://colab.research.google.com/github/pm-ssingh/CF/blob/main/My_First_Colab_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'I am a Product Manager' *100
# Out:
# 'I am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a Product ManagerI am a 
# ...

# %%
a = 10
b = 5

addition = a + b
division = a / b

addition, division
# Out:
# (15, 2.0)

# %%
numbers = [1, 2, 3, 4, 5]
sum_of_squares = 0
for number in numbers:
    square = number ** 2
    sum_of_squares += square
print(f"The numbers are: {numbers}")
print(f"The sum of their squares is: {sum_of_squares}")
# Out:
# The numbers are: [1, 2, 3, 4, 5]
# The sum of their squares is: 55
